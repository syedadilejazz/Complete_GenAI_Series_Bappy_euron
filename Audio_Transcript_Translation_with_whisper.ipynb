# %% [markdown]
# <a href="https://colab.research.google.com/github/syedadilejazz/Complete_GenAI_Series_Bappy_euron/blob/main/Audio_Transcript_Translation_with_whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Requirement.txt
#!pip install openai==0.28
# !pip install python-dotenv
# !pip install flask
# Out:
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)

# %%
#import openai
#print(openai.__version__)

# %% [markdown]
# Demo

# %%
# !pip install --upgrade pip
# !pip install --upgrade transformers datasets[audio] accelerate
# Out:
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)

# %%
from google.colab import files

# Upload audio from your Mac
uploaded = files.upload()

audio_file = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-9854da0a-f8c9-45a9-bd12-e957c4332818" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9854da0a-f8c9-45a9-bd12-e957c4332818">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Demo
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3-turbo"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
)

# %%
# Transcribe your uploaded audio
result = pipe(audio_file,return_timestamps=True, generate_kwargs={"language": "bengali"})
print(result["text"])

# %%
#whisper is a state-of-art model for automatic speech recognition asr and speech translation proposed in the paper robust speech recognition via large-scale weak supervision by alice referred from open ai trained on greater than 5 million uh hours of labeled data whisper demonstrates a strong ability to generate too many data sets and domain in a zero shot setting
#विस्पर is a state-of-art model for automatic speech recognition asr and speech translation proposed in the paper robust speech recognition via large-scale weak supervision by ls reford from open ai trained on greater than 5 million uh hours of label data whisper demonstrates a और अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी तो अबलेटी

# %%
#app.py
#Flask application-to be continued
import os
import dotenv import load_dotenv
from flask import Flask,request,jsonify,render_template

app=Flask(__name__)
app.config["UPLOAD_FOLDER"]="sample_data"

@app.route("/",methods=["GET","POST"])
def main():
  if request.method=="POST":
    #on which language the translation should happen
    language=request.form["language"]
    if "file" not in request.files:
      return redirect(request.url)
    file=request.files["file"]
# Out:
#   File "/tmp/ipykernel_5559/987035665.py", line 3
#     import dotenv import load_dotenv
#                   ^
# SyntaxError: invalid syntax
