# %% [markdown]
# <a href="https://colab.research.google.com/github/syedadilejazz/Complete_GenAI_Series_Bappy_euron/blob/main/Multi_dataframe_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In LangChain, the Agent can access many dataframes at once

# %% [markdown]
# #01: Install All the Required Packages

# %%
# !pip install langchain langchain_experimental
# !pip install watermark
# !pip install openai
# !pip install -U langchain-openai

# %% [markdown]
# #02: Import All The Required Libraries

# %%
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_openai import OpenAI

# %%
import pandas as pd

# %% [markdown]
# #03: Setup the Environment

# %%
os.environ['OPENAI_API_KEY'] = ""

# %% [markdown]
# #04:Data

# %%
url = "https://raw.githubusercontent.com/adamerose/datasets/master/titanic.csv"
df=pd.read_csv(url)
print(df.shape)
df.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #05: Single DataFrame Example
# Agent can interact with Single DataFrame

# %%
llm=OpenAI()

# %%
agent=create_pandas_dataframe_agent(llm, df, verbose=True, allow_dangerous_code=True)

# %%
agent.run("How many rows are there")
# Out:
# /tmp/ipykernel_3496/1005132620.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain-classic 0.1.0 and will be removed in 2.0.0. Use `invoke` instead.
#   agent.run("How many rows are there")
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_3496/1005132620.py in <cell line: 0>()
# ----> 1 agent.run("How many rows are there")
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     235                 # suppressed by `suppress_langchain_deprecation_warning()`.
#     236                 warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 237             return wrapped(*args, **kwargs)
#     238
#     239         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# ...

# %%
agent.run("How many people have more than 23 age")

# %%
#06: Multi DataFrame Example
Agent can also interact with Multiple DataFrames passed in a list
# Out:
#   File "/tmp/ipykernel_3496/3439737372.py", line 2
#     Agent can also interact with Multiple DataFrames passed in a list
#           ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df1=df.copy()

# %%
df1["age"] = df1["age"].fillna(df1["age"].mean())

# %%
agent=create_pandas_dataframe_agent(llm, [df, df1], verbose=True,allow_dangerous_code=True)

# %%
agent.run("How many rows in the age column are different")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_3496/1588112348.py in <cell line: 0>()
# ----> 1 agent.run("How many rows in the age column are different")
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     235                 # suppressed by `suppress_langchain_deprecation_warning()`.
#     236                 warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 237             return wrapped(*args, **kwargs)
#     238
#     239         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.13/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     630                 msg = "`run` supports only one positional argument."
# ...

# %%
df2=df1.copy()

# %%
df2["Age_Multiplied"]=df1["age"] * 2

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Age_Multiplied
# 0    man        True  NaN  Southampton    no  False            44.0
# 1  woman       False    C    Cherbourg   yes  False            76.0
# 2  woman       False  NaN  Southampton   yes   True            52.0
# 3  woman       False    C  Southampton   yes  False            70.0
# 4    man        True  NaN  Southampton    no   True            70.0

# %%
agent=create_pandas_dataframe_agent(llm, [df,df1, df2], verbose=True, allow_dangerous_code=True)

# %%
agent.run("Are the number of columns same in all the dataframe")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_3496/1756546525.py in <cell line: 0>()
# ----> 1 agent.run("Are the number of columns same in all the dataframe")
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     235                 # suppressed by `suppress_langchain_deprecation_warning()`.
#     236                 warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 237             return wrapped(*args, **kwargs)
#     238
#     239         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.13/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     630                 msg = "`run` supports only one positional argument."
# ...
