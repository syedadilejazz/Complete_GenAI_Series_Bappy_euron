# %% [markdown]
# <a href="https://colab.research.google.com/github/syedadilejazz/Complete_GenAI_Series_Bappy_euron/blob/main/Rag_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-community langchain-openai
# !pip install -U python-dotenv
# !pip install -U streamlit
# !pip install -U langchain-experimental
# !pip install -U sentence-transformers
# !pip install -U langchain-chroma chromadb
# !pip install -U langchainhub
# !pip install -U unstructured
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 97.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.17
#     Uninstalling langchain-1.3.17:
#       Successfully uninstalled langchain-1.3.17
# ...

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
URLs=[
    'https://blog.gopenai.com/paper-review-llama-2-open-foundation-and-fine-tuned-chat-models-23e539522acb',
    'https://www.mosaicml.com/blog/mpt-7b',
    'https://stability.ai/blog/stability-ai-launches-the-first-of-its-stablelm-suite-of-language-models',
    'https://lmsys.org/blog/2023-03-30-vicuna/'
]

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

loader = UnstructuredURLLoader(
    urls=URLs
)

data = loader.load()

# %%
len(data)
# Out:
# 4

# %%
data
# Out:
# [Document(metadata={'source': 'https://blog.gopenai.com/paper-review-llama-2-open-foundation-and-fine-tuned-chat-models-23e539522acb'}, page_content='Please enable cookies.\n\nSorry, you have been blocked\n\nYou are unable to access medium.com\n\nWhy have I been blocked?\n\nThis website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.\n\nWhat can I do to resolve this?\n\nYou can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.\n\nCloudflare Ray ID: a3546c3779ab585b • Your IP: 35.240.168.66 • Performance & security by Cloudflare'),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
#split text
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,

)
docs=text_splitter.split_documents(data)
print("Total number of documents:",len(docs))
# Out:
# Total number of documents: 61

# %%
docs[0]
# Out:
# Document(metadata={'source': 'https://blog.gopenai.com/paper-review-llama-2-open-foundation-and-fine-tuned-chat-models-23e539522acb'}, page_content='Please enable cookies.\n\nSorry, you have been blocked\n\nYou are unable to access medium.com\n\nWhy have I been blocked?\n\nThis website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.\n\nWhat can I do to resolve this?\n\nYou can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.\n\nCloudflare Ray ID: a3546c3779ab585b • Your IP: 35.240.168.66 • Performance & security by Cloudflare')

# %%
#Embedding Models

# %%
# !pip install -U langchain-chroma chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 88.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 102.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
# ...

# %%
from langchain_chroma import Chroma

from langchain_openai import OpenAI
from langchain_openai import OpenAIEmbeddings

# %%
OPEN_AI_API_KEY=""

# %%
#knowledge Base
vectorstore=Chroma.from_documents(documents=docs,embedding=OpenAIEmbeddings(openai_api_key=OPEN_AI_API_KEY))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_2478/3453112036.py in <cell line: 0>()
#       1 #knowledge Base
# ----> 2 vectorstore=Chroma.from_documents(documents=docs,embedding=OpenAIEmbeddings(openai_api_key=OPEN_AI_API_KEY))
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/langchain_openai/embeddings/base.py in validate_environment(self)
#     435                     "api_key": sync_api_key_value,
#     436                 }
# --> 437                 self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     438         if not self.async_client:
#     439             if self.openai_proxy and not self.http_async_client:
#
# ...

# %%
retriver=vectorstore.as_retriever(search_type="similarity",search_kwargs={k:3})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2478/1696803990.py in <cell line: 0>()
# ----> 1 retriver=vectorstore.as_retriever(search_type="similarity",search_kwargs={k:3})
#
# NameError: name 'vectorstore' is not defined

# %%
retriver_docs=retriver.invoke("What kind of services they provide?")
len(retriver_docs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2478/18754510.py in <cell line: 0>()
# ----> 1 retriver_docs=retriver.invoke("What kind of services they provide?")
#       2 len(retriver_docs)
#
# NameError: name 'retriver' is not defined

# %%
#LLM

# %%
from langchain_chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompt import ChatPromptTemplate
system_prompt=(
    "You are an assistant for question-answering task."
    "Use the following peices of retrieved conext to answer."
    "the question. If you dont know the answer , say that you"
    "dont know. Use three sentences maximum and keep the"
    "answer concise."
    "\n\n"
    "{context}")
prompt=ChatPromptTemplate.from_messages([("system",system_prompt),("human","{input}")])


)
# Out:
#   File "/tmp/ipykernel_1496/3085242220.py", line 15
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
question_answer_chain=create_stuff_documents_chain(llm,prompt)
rag_chain=create_retrieval_chain(retriver,question_answer_chain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1496/1422614752.py in <cell line: 0>()
# ----> 1 question_answer_chain=create_stuff_documents_chain(llm,prompt)
#       2 rag_chain=create_retrieval_chain(retriver,question_answer_chain)
#
# NameError: name 'create_stuff_documents_chain' is not defined

# %%
response=rag_chain.invoke({"input":"What kind of the services they provide?"})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1496/796464559.py in <cell line: 0>()
# ----> 1 response=rag_chain.invoke({"input":"What kind of the services they provide?"})
#       2 print(response["answer"])
#
# NameError: name 'rag_chain' is not defined
