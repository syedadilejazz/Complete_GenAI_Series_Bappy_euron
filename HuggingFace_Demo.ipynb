# %% [markdown]
# Installation

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (5.13.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (1.22.0)
# Requirement already satisfied: numpy>=1.17 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex>=2025.10.22 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (2026.6.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (0.26.7)
# Requirement already satisfied: safetensors>=0.8.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.5.0)
# Requirement already satisfied: certifi in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.0)

# %%
#pip install torch torchvision torchaudio

# %%
#!pip install --upgrade pip

#!pip uninstall -y numpy scipy scikit-learn transformers

#!pip install numpy scipy scikit-learn transformers

# %% [markdown]
# HuggingFace tasks

# %%
from transformers import pipeline
#Here all kind of task can be done for NLP.-Text classification, text generation, question answering, summarization, translation, etc.
#We can use the pipeline function to perform these tasks. We just need to specify the task
classifier = pipeline('text-classification')
#Token Classification:Assigning labels to tokens in a text sequence. For example, Named Entity Recognition (NER) is a token classification task where we identify entities like names, organizations, locations, etc. in a text.
token_classifier = pipeline('token-classification')
#Question Ansering:Extracting answers from a given context based on a question.
question_answerer = pipeline('question-answering')
#Text Generation:Generating text based on a given prompt. This can be used for tasks like story generation, code generation, etc.
text_generator = pipeline('text-generation')
#Summarization:Generating a concise summary of a given text.
summarizer = pipeline('summarization')
#Translation:Translating text from one language to another.
translator = pipeline('translation_en_to_fr',model='tencent/Hy-MT2-1.8B')  # Example: English to French translation
#Text2text Generation:Generating text based on a given input text. This can be used for tasks like paraphrasing, text completion, etc.
text2text_generator = pipeline('text2text-generation')
fill_masker = pipeline('fill-mask')  # Filling in missing words in a text sequence
#Image Classification:Classifying images into predefined categories.
image_classifier = pipeline('image-classification')
table_qa = pipeline('table-question-answering')  # Answering questions based on tabular data
doc_qa = pipeline('document-question-answering')  # Answering questions based on document data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from transformers import pipeline
#       2 #Here all kind of task can be done for NLP.-Text classification, text generation, question answering, summarization, translation, etc.
#       3 #We can use the pipeline function to perform these tasks. We just need to specify the task
#       4 classifier = pipeline('text-classification')
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2305, in _LazyModule.__getattr__(self, name)
#    2303 elif name in self._class_to_module:
#    2304     try:
# -> 2305         module = self._get_module(self._class_to_module[name])
#    2306         value = getattr(module, name)
#    2307     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2308         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2309         # non-Fast symbol from the same module when available. This lets us keep only one
#    2310         # backend tokenizer class while preserving legacy public names.
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2539, in _LazyModule._get_module(self, module_name)
#    2537     return importlib.import_module("." + module_name, self.__name__)
#    2538 except Exception as e:
# -> 2539     raise e
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2537, in _LazyModule._get_module(self, module_name)
#    2535 def _get_module(self, module_name: str):
#    2536     try:
# -> 2537         return importlib.import_module("." + module_name, self.__name__)
#    2538     except Exception as e:
#    2539         raise e
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/__init__.py:29
#      27 from ..image_processing_utils import BaseImageProcessor
#      28 from ..models.auto.configuration_auto import AutoConfig
# ---> 29 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#      30 from ..models.auto.image_processing_auto import IMAGE_PROCESSOR_MAPPING, AutoImageProcessor
#      31 from ..models.auto.modeling_auto import AutoModelForDepthEstimation, AutoModelForImageToImage
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/feature_extraction_auto.py:25
#      23 from ...feature_extraction_utils import FeatureExtractionMixin
#      24 from ...utils import CONFIG_NAME, FEATURE_EXTRACTOR_NAME, PROCESSOR_NAME, cached_file, logging, safe_load_json_file
# ---> 25 from .auto_factory import _LazyAutoMapping
#      26 from .auto_mappings import FEATURE_EXTRACTOR_MAPPING_NAMES
#      27 from .configuration_auto import (
#      28     CONFIG_MAPPING_NAMES,
#      29     AutoConfig,
#      30     model_type_to_module_name,
#      31     replace_list_option_in_docstrings,
#      32 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:42
#      38 from .configuration_auto import AutoConfig, model_type_to_module_name, replace_list_option_in_docstrings
#      41 if is_torch_available():
# ---> 42     from ...generation import GenerationMixin
#      45 logger = logging.get_logger(__name__)
#      47 _T = TypeVar("_T")
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2305, in _LazyModule.__getattr__(self, name)
#    2303 elif name in self._class_to_module:
#    2304     try:
# -> 2305         module = self._get_module(self._class_to_module[name])
#    2306         value = getattr(module, name)
#    2307     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2308         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2309         # non-Fast symbol from the same module when available. This lets us keep only one
#    2310         # backend tokenizer class while preserving legacy public names.
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2539, in _LazyModule._get_module(self, module_name)
#    2537     return importlib.import_module("." + module_name, self.__name__)
#    2538 except Exception as e:
# -> 2539     raise e
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:2537, in _LazyModule._get_module(self, module_name)
#    2535 def _get_module(self, module_name: str):
#    2536     try:
# -> 2537         return importlib.import_module("." + module_name, self.__name__)
#    2538     except Exception as e:
#    2539         raise e
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:53
#      46 from ..utils import (
#      47     ModelOutput,
#      48     TransformersKwargs,
#      49     is_accelerate_available,
#      50     logging,
#      51 )
#      52 from ..utils.generic import is_flash_attention_requested
# ---> 53 from .candidate_generator import (
#      54     AssistantVocabTranslatorCache,
#      55     AssistedCandidateGenerator,
#      56     AssistedCandidateGeneratorDifferentTokenizers,
#      57     CandidateGenerator,
#      58     EarlyExitCandidateGenerator,
#      59     PromptLookupCandidateGenerator,
#      60     SinglePositionMultiTokenCandidateGenerator,
#      61     UniversalSpeculativeDecodingGenerator,
#      62     _prepare_attention_mask,
#      63     _prepare_position_ids,
#      64     _prepare_token_type_ids,
#      65 )
#      66 from .configuration_utils import (
#      67     ALL_STATIC_CACHE_IMPLEMENTATIONS,
#      68     DEPRECATED_STATIC_CACHE_IMPLEMENTATIONS,
#    (...)
#      71     GenerationMode,
#      72 )
#      73 from .continuous_batching import ContinuousMixin
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/candidate_generator.py:31
#      27 from .logits_process import LogitsProcessorList, MinLengthLogitsProcessor, SuppressTokensLogitsProcessor
#      30 if is_sklearn_available():
# ---> 31     from sklearn.metrics import roc_curve
#      33 if TYPE_CHECKING:
#      34     from ..modeling_utils import PreTrainedModel
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "callback",
#    (...)
#     112     "compose",
#     113 ]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:20
#      18 from sklearn._config import config_context, get_config
#      19 from sklearn.exceptions import InconsistentVersionWarning
# ---> 20 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      22 from sklearn.utils._param_validation import validate_parameter_constraints
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_array, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _is_numpy_namespace,
#      27     _max_precision_float_dtype,
#      28     get_namespace,
#      29     get_namespace_and_device,
#      30     move_to,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:23
#      21 from sklearn.externals.array_api_compat import numpy as np_compat
#      22 from sklearn.utils._dataframe import is_df_or_series
# ---> 23 from sklearn.utils.fixes import parse_version
#      25 # TODO: complete __all__
#      26 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/fixes.py:19
#      16 import scipy.stats
#      18 try:
# ---> 19     import pandas as pd
#      20 except ImportError:
#      21     pd = None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import sys
print(sys.executable)

import numpy
print("NumPy:", numpy.__version__)

import pandas
print("Pandas:", pandas.__version__)
# Out:
# /Users/syedadilejaz/anaconda3/bin/python
# NumPy: 2.4.6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       4 import numpy
#       5 print("NumPy:", numpy.__version__)
# ----> 7 import pandas
#       8 print("Pandas:", pandas.__version__)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import sys
print(sys.executable)
# Out:
# /Users/syedadilejaz/anaconda3/bin/python

# %% [markdown]
# Sentiment Analysis(Kind of Text Classification)

# %%
# !pip install PyTorch
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105731510>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pytorch/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x103c18790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pytorch/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052e3890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pytorch/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105722c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pytorch/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105723cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pytorch/
# ERROR: Could not find a version that satisfies the requirement PyTorch (from versions: none)
# ERROR: No matching distribution found for PyTorch

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")#Download default model for sentiment analysis
result=classifier("I was so not happy withthe Last Mission Impossible movie")
print(result)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 2
#       1 from transformers import pipeline
# ----> 2 classifier = pipeline("sentiment-analysis")#Download default model for sentiment analysis
#       3 result=classifier("I was so not happy withthe Last Mission Impossible movie")
#       4 print(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/__init__.py:807, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     805 if isinstance(model, str) or framework is None:
#     806     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 807     framework, model = infer_framework_load_model(
#     808         model,
#     809         model_classes=model_classes,
#     810         config=config,
#     811         framework=framework,
#     812         task=task,
#     813         **hub_kwargs,
#     814         **model_kwargs,
#     815     )
#     817 model_config = model.config
#     818 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:219, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     193 """
#     194 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     195
#    (...)
#     216     `Tuple`: A tuple framework, model.
#     217 """
#     218 if not is_tf_available() and not is_torch_available():
# --> 219     raise RuntimeError(
#     220         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     221         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     222         "To install PyTorch, read the instructions at https://pytorch.org/."
#     223     )
#     224 if isinstance(model, str):
#     225     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.

# %%
pipeline(task="sentiment-analysis")("I am confused with the Baribie movie")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pipeline(task="sentiment-analysis")("I am confused with the Baribie movie")
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/__init__.py:807, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     805 if isinstance(model, str) or framework is None:
#     806     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 807     framework, model = infer_framework_load_model(
#     808         model,
#     809         model_classes=model_classes,
#     810         config=config,
#     811         framework=framework,
#     812         task=task,
#     813         **hub_kwargs,
#     814         **model_kwargs,
#     815     )
#     817 model_config = model.config
#     818 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:219, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     193 """
#     194 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     195
#    (...)
#     216     `Tuple`: A tuple framework, model.
#     217 """
#     218 if not is_tf_available() and not is_torch_available():
# --> 219     raise RuntimeError(
#     220         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     221         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     222         "To install PyTorch, read the instructions at https://pytorch.org/."
#     223     )
#     224 if isinstance(model, str):
#     225     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.

# %%
pipeline(task="sentiment-analysis",model="facebook/bart-large-mnli")\
("everyday lots of llm papers are publisehed about LLMs Evaluation.\
lots of them looks very promising\
I am not sure if we cab actaully Evaluate LLMS.\
There is still lots to do.\
Don't you think?"
)
# Out:
# ---------------------------------------------------------------------------
# LocalEntryNotFoundError                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:428, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     426 try:
#     427     # Load from URL or cache if already cached
# --> 428     resolved_file = hf_hub_download(
#     429         path_or_repo_id,
#     430         filename,
#     431         subfolder=None if len(subfolder) == 0 else subfolder,
#     432         repo_type=repo_type,
#     433         revision=revision,
#     434         cache_dir=cache_dir,
#     435         user_agent=user_agent,
#     436         force_download=force_download,
#     437         proxies=proxies,
#     438         resume_download=resume_download,
#     439         token=token,
#     440         local_files_only=local_files_only,
#     441     )
#     442 except GatedRepoError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1291, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1290     else:
# -> 1291         raise LocalEntryNotFoundError(
#    1292             "Connection error, and we cannot find the requested files in"
#    1293             " the disk cache. Please try again or make sure your Internet"
#    1294             " connection is on."
#    1295         )
#    1297 # From now on, etag and commit_hash are not None.
#
# LocalEntryNotFoundError: Connection error, and we cannot find the requested files in the disk cache. Please try again or make sure your Internet connection is on.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pipeline(task="sentiment-analysis",model="facebook/bart-large-mnli")\
#       2 ("everyday lots of llm papers are publisehed about LLMs Evaluation.\
#       3 lots of them looks very promising\
#       4 I am not sure if we cab actaully Evaluate LLMS.\
#       5 There is still lots to do.\
#       6 Don't you think?"
#       7 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/__init__.py:724, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     722     hub_kwargs["_commit_hash"] = config._commit_hash
#     723 elif config is None and isinstance(model, str):
# --> 724     config = AutoConfig.from_pretrained(model, _from_pipeline=task, **hub_kwargs, **model_kwargs)
#     725     hub_kwargs["_commit_hash"] = config._commit_hash
#     727 custom_tasks = {}
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1007, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1005 kwargs["name_or_path"] = pretrained_model_name_or_path
#    1006 trust_remote_code = kwargs.pop("trust_remote_code", None)
# -> 1007 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1008 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1009 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/configuration_utils.py:620, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     618 original_kwargs = copy.deepcopy(kwargs)
#     619 # Get config dict associated with the base config file
# --> 620 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     621 if "_commit_hash" in config_dict:
#     622     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/configuration_utils.py:675, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     671 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME)
#     673 try:
#     674     # Load from local folder or from cache or download from model Hub and cache
# --> 675     resolved_config_file = cached_file(
#     676         pretrained_model_name_or_path,
#     677         configuration_file,
#     678         cache_dir=cache_dir,
#     679         force_download=force_download,
#     680         proxies=proxies,
#     681         resume_download=resume_download,
#     682         local_files_only=local_files_only,
#     683         token=token,
#     684         user_agent=user_agent,
#     685         revision=revision,
#     686         subfolder=subfolder,
#     687         _commit_hash=commit_hash,
#     688     )
#     689     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     690 except EnvironmentError:
#     691     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     692     # the original exception.
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:468, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     466     if not _raise_exceptions_for_missing_entries or not _raise_exceptions_for_connection_errors:
#     467         return None
# --> 468     raise EnvironmentError(
#     469         f"We couldn't connect to '{HUGGINGFACE_CO_RESOLVE_ENDPOINT}' to load this file, couldn't find it in the"
#     470         f" cached files and it looks like {path_or_repo_id} is not the path to a directory containing a file named"
#     471         f" {full_filename}.\nCheckout your internet connection or see how to run the library in offline mode at"
#     472         " 'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     473     ) from e
#     474 except EntryNotFoundError as e:
#     475     if not _raise_exceptions_for_missing_entries:
#
# OSError: We couldn't connect to 'https://huggingface.co' to load this file, couldn't find it in the cached files and it looks like facebook/bart-large-mnli is not the path to a directory containing a file named config.json.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
