# %% [markdown]
# <a href="https://colab.research.google.com/github/syedadilejazz/Complete_GenAI_Series_Bappy_euron/blob/main/Custom_Website_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain langchain-community
# !pip -q install pypdf
# !pip -q install senetence_transformers
# !pip install openai
# !pip install tiktoken
# !pip install -U langchain-text-splitters langchain-openai faiss-cpu
# !pip install -U langchain-unstructured unstructured
# Out:
# ERROR: Could not find a version that satisfies the requirement senetence_transformers (from versions: none)
# ERROR: No matching distribution found for senetence_transformers
# ...

# %%
# !pip install tokenizers
# !pip install faiss-cpu
# !pip -q install unstructured

# %%
# !pip install numpy==1.24.4
# !pip install nltk==3.9.1
# Out:
# ...
#   Using cached numpy-1.24.4.tar.gz (10.9 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ...

# %%
import sys
import os
import torch
import textwrap

from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
#from langchain.chains imprt RetrievalQAWithSourcesChain

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
os.environ["OPENAI_API_KEY"]=""

# %%
URLs=[
    'https://blog.gopenai.com/paper-review-llama-2-open-foundation-and-fine-tuned-chat-models-23e539522acb',
    'https://www.mosaicml.com/blog/mpt-7b',
    'https://stability.ai/blog/stability-ai-launches-the-first-of-its-stablelm-suite-of-language-models',
    'https://lmsys.org/blog/2023-03-30-vicuna/'
]

# %%
from langchain_unstructured import UnstructuredLoader
data = []

for urls in URLs:
    loader = UnstructuredLoader(url=urls)
    data.extend(loader.load())

print(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1819/4243126119.py in <cell line: 0>()
#       4 for urls in URLs:
#       5     loader = UnstructuredLoader(url=urls)
# ----> 6     data.extend(loader.load())
#       7
#       8 print(data)
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/document_loaders/base.py in load(self)
#      41             The documents.
#      42         """
# ---> 43         return list(self.lazy_load())
#      44
#      45     async def aload(self) -> list[Document]:
#
# /usr/local/lib/python3.13/dist-packages/langchain_unstructured/document_loaders.py in lazy_load(self)
#     178
#     179         # Call _UnstructuredBaseLoader normally since file and file_path are not lists
# --> 180         yield from load_file(f=self.file, f_path=self.file_path)
#     181
#     182
#
# ...

# %%
len(data)
# Out:
# 0

# %%
text_splitter=CharacterTextSplitter(separator='\n'
,chunk_size=1000,
chunk_overlap=200
)

# %%
text_chunks=text_splitter.split_documents(data)
text_chunks
# Out:
# []

# %%
len(text_chunks)
# Out:
# 0

# %%
text_chunks[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1819/2001203030.py in <cell line: 0>()
# ----> 1 text_chunks[0]
#
# IndexError: list index out of range

# %%
text_chunks[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1819/3447128196.py in <cell line: 0>()
# ----> 1 text_chunks[1]
#
# IndexError: list index out of range

# %%
embeddings=OpenAIEmbeddings()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_1819/2276573386.py in <cell line: 0>()
# ----> 1 embeddings=OpenAIEmbeddings()
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/langchain_openai/embeddings/base.py in validate_environment(self)
#     435                     "api_key": sync_api_key_value,
#     436                 }
# --> 437                 self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     438         if not self.async_client:
#     439             if self.openai_proxy and not self.http_async_client:
#
# ...

# %%
query_result=embeddings.embed_query("Hello World")
len(query_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/3677948724.py in <cell line: 0>()
# ----> 1 query_result=embeddings.embed_query("Hello World")
#       2 len(query_result)
#
# NameError: name 'embeddings' is not defined

# %%
vectorstore=FAISS.from_documents(text_chunks,embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/1229692276.py in <cell line: 0>()
# ----> 1 vectorstore=FAISS.from_documents(text_chunks,embeddings)
#
# NameError: name 'embeddings' is not defined

# %%
llm=ChatOpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_1819/1964788120.py in <cell line: 0>()
# ----> 1 llm=ChatOpenAI()
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     134     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135         """"""  # noqa: D419  # Intentional blank docstring
# --> 136         super().__init__(*args, **kwargs)
#     137
#     138     @classmethod
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/langchain_openai/chat_models/base.py in validate_environment(self)
#    1439                 "api_key": async_api_key_value,
#    1440             }
# -> 1441             self.root_async_client = openai.AsyncOpenAI(
#    1442                 **client_params,
#    1443                 **async_specific,  # type: ignore[arg-type]
#
# ...

# %%
llm.predict("Please provide summary of Book Harry Potter")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/3339469721.py in <cell line: 0>()
# ----> 1 llm.predict("Please provide summary of Book Harry Potter")
#
# NameError: name 'llm' is not defined

# %%
chain=RetrievalQAWithSourceChain.from_llm(llm=llm,retriver=vectorstore.as_retriever())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/693873054.py in <cell line: 0>()
# ----> 1 chain=RetrievalQAWithSourceChain.from_llm(llm=llm,retriver=vectorstore.as_retriever())
#
# NameError: name 'RetrievalQAWithSourceChain' is not defined

# %%
result=chain({"question":"How good is Vicuna?"},return_only_outputs=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/48497998.py in <cell line: 0>()
# ----> 1 result=chain({"question":"How good is Vicuna?"},return_only_outputs=True)
#
# NameError: name 'chain' is not defined

# %%
result=chain({"question":"How good is Vicuna?"},return_only_outputs=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/48497998.py in <cell line: 0>()
# ----> 1 result=chain({"question":"How good is Vicuna?"},return_only_outputs=True)
#
# NameError: name 'chain' is not defined

# %%
result["answer"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/1498041723.py in <cell line: 0>()
# ----> 1 result["answer"]
#
# NameError: name 'result' is not defined

# %%
result=chain({"question":"Hoe does a Llama 2 outperforms other models"},return_only_outputs=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/1786440494.py in <cell line: 0>()
# ----> 1 result=chain({"question":"Hoe does a Llama 2 outperforms other models"},return_only_outputs=True)
#
# NameError: name 'chain' is not defined

# %%
result["answer"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1819/1498041723.py in <cell line: 0>()
# ----> 1 result["answer"]
#
# NameError: name 'result' is not defined

# %%
while True:
  query=input(f"Prompt: ")
  if query=="exit":
    print("Exiting")
    sys.exit()
  if query =="":
    continue
  reusult=chain({'question':query})
  print(f"Answer:" +result['answer'])
# Out:
# Prompt: exit
# Exiting
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
