# %% [markdown]
# <a href="https://colab.research.google.com/github/syedadilejazz/DBSCAN-Algorithm/blob/master/Text_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Connect colab to GoogleDrive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
os.getcwd()
# Out:
# '/Users/syedadilejaz/Complete_GenAI_Series_Bappy_euron'

# %%
#df = pd.read_csv('/Users/syedadilejaz/data/IMDB Dataset.csv', escapechar='\\', quotechar='"')

df=pd.read_csv('data/IMDB Dataset 2.csv', escapechar='\\', quotechar='"')
print("Shape",df.shape)
print("Columns",df.columns)
df.head(3)
# Out:
# Shape (50000, 2)
# Columns Index(['review', 'sentiment'], dtype='object')
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Lower Case

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
df["review"]=df["review"].apply(lambda x:x.lower())
df["sentiment"]=df["sentiment"].apply(lambda x:x.lower())
df.head(3)
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive

# %% [markdown]
# remove_html_tags

# %%
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    """
    < matched opening angle bracket
    .*? matched any character(.),any number of time(*),but non-greedy(?)
    > matched closing angle bracket
    """
    return pattern.sub(r'', text)#Replaces everything that matched the pattern with empty string

# %%
text = "<html><body><p>Movie 1</pppppppppp><p> Actor - Aamir Khan</p><p> Click here to <a href='http://google.com'>download</a></p></body></html>"

# %%
remove_html_tags(text)
# Out:
# 'Movie 1 Actor - Aamir Khan Click here to download'

# %%
df['review'] = df['review'].apply(remove_html_tags)

# %%
df["review"][3]
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %% [markdown]
# remove_url

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
text1 = 'Check out my youtube http://www.youtube.com/dswithbappy dswithbappy'
text2 = 'Check out my linkedin https://www.linkedin.com/in/boktiarahmed73/'
text3 = 'Google search here www.google.com'
text4 = 'For data click https://www.kaggle.com/'

# %%
remove_url(text1)
# Out:
# 'Check out my youtube  dswithbappy'

# %%
df['review'] = df['review'].apply(remove_url)

# %% [markdown]
# punctuation handling

# %%
import string,time
exclude=string.punctuation
exclude
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
    for char in exclude:
        text = text.replace(char,'')
    return text

# %%
text = 'string. With.@!#$%^&*()_+ Punctuation?'

# %%
start = time.time()
print(remove_punc(text))
time1 = time.time() - start
print(time1*50000)
# Out:
# string With Punctuation
# 2.658367156982422

# %%
def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))

# %%
start = time.time()
remove_punc1(text)
time2 = time.time() - start
print(time2*50000)
# Out:
# 1.6570091247558594

# %%
time1/time2
# Out:
# 1.60431654676259

# %%
df["review"][5]
# Out:
# 'probably my all-time favorite movie, a story of selflessness, sacrifice and dedication to a noble cause, but it\'s not preachy or boring. it just never gets old, despite my having seen it some 15 or more times in the last 25 years. paul lukas\' performance brings tears to my eyes, and bette davis, in one of her very few truly sympathetic roles, is a delight. the kids are, as grandma says, more like "dressed-up midgets" than children, but that only makes them more fun to watch. and the mother\'s slow awakening to what\'s happening in the world and under her own roof is believable and startling. if i had a dozen thumbs, they\'d all be "up" for this movie.'

# %%
df["review"]=df["review"].apply(remove_punc)
df["review"][5]
# Out:
# 'probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some 15 or more times in the last 25 years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie'

# %% [markdown]
# chat_conversion handle

# %%
chat_words = {
    'AFAIK':'As Far As I Know',
    'AFK':'Away From Keyboard',
    'ASAP':'As Soon As Possible',




    "FYI": "For Your Information",
    "ASAP": "As Soon As Possible",
    "BRB": "Be Right Back",
    "BTW": "By The Way",
    "OMG": "Oh My God",
    "IMO": "In My Opinion",
    "LOL": "Laugh Out Loud",
    "TTYL": "Talk To You Later",
    "GTG": "Got To Go",
    "TTYT": "Talk To You Tomorrow",
    "IDK": "I Don't Know",
    "TMI": "Too Much Information",
    "IMHO": "In My Humble Opinion",
    "ICYMI": "In Case You Missed It",
    "AFAIK": "As Far As I Know",
    "BTW": "By The Way",
    "FAQ": "Frequently Asked Questions",
    "TGIF": "Thank God It's Friday",
    "FYA": "For Your Action",
    "ICYMI": "In Case You Missed It",
}

# %%
def chat_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words:
            new_text.append(chat_words[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
chat_conversion('Do this work FYA')
# Out:
# 'Do this work For Your Action'

# %%
df["review"]=df["review"].apply(chat_conversion)

# %% [markdown]
# incorrect_text handling

# %%
#!pip3 install textblob
from textblob import TextBlob

# %%
incorrect_text = 'ceertain conditionas duriing seveal ggenerations aree moodified in the saame maner. hindiiii bolo'

textBlb = TextBlob(incorrect_text)

textBlb.correct().string
# Out:
# 'certain conditions during several generations are modified in the same manner. hindiiii bold'

# %%
def incorrect_text_func(incorrect_text):
    textBlb = TextBlob(incorrect_text)
    return textBlb.correct().string

# safer: keep original and write fixes to a new column
df["review_fixed"] = df["review"]
df.loc[0:99, "review_fixed"] = df.loc[0:99, "review_fixed"].apply(incorrect_text_func)#2 mins

# %%
# ...existing code...
import sys
# !{sys.executable} -m pip install -q pyspellchecker joblib

from spellchecker import SpellChecker
from joblib import Parallel, delayed

spell = SpellChecker(distance=1)  # distance=1 is fast; increase if needed

def quick_spell_fix(text):
    if not isinstance(text, str) or not text.strip():
        return text
    out = []
    for w in text.split():
        if w.isalpha():
            # keep case of original token (lower for lookup)
            cand = spell.correction(w.lower())
            out.append(cand if cand is not None else w)
        else:
            out.append(w)
    return " ".join(out)

# Test on small sample
df["review_fixed_spell"] = df["review"]
df.loc[0:99, "review_fixed_spell"] = df.loc[0:99, "review_fixed_spell"].apply(incorrect_text_func)

# %%
(df.loc[0:99, "review_fixed"] == df.loc[0:99, "review_fixed_spell"]).all()
# Out:
# True

# %% [markdown]
# stopwords

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# False

# %%
stopwrds=(list(stopwords.words('english')))
print("Stopwords lenghth",len(stopwrds))
print(stopwrds[0:10])
# Out:
# Stopwords lenghth 198
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
df.loc[0:99,"review"] = df.loc[0:99,"review"].apply(remove_stopwords)

# %%
remove_stopwords('probably my all-time favorite movie, a story of selflessness, sacrifice and dedication to a noble cause, but it\'s not preachy or boring. it just never gets old, despite my having seen it some 15 or more times')
# Out:
# 'probably  all-time favorite movie,  story  selflessness, sacrifice  dedication   noble cause,    preachy  boring.   never gets old, despite   seen   15   times'

# %%
df["review"][10]
# Out:
# 'phil  alien  one   quirky films   humour  based around  oddness  everything rather  actual punchlinesat first    odd  pretty funny    movie progressed  didnt find  jokes  oddness funny anymoreits  low budget film thats never  problem      pretty interesting characters  eventually   lost interesti imagine  film would appeal   stoner   currently partakingfor something similar  better try brother  another planet'

# %%
test=remove_stopwords(df["review"][10])
test
# Out:
# 'phil alien one quirky films humour based around oddness everything rather actual punchlinesat first odd pretty funny movie progressed didnt find jokes oddness funny anymoreits low budget film thats never problem pretty interesting characters eventually lost interesti imagine film would appeal stoner currently partakingfor something similar better try brother another planet'

# %%
" ".join(set(df["review"][10].split()).symmetric_difference(set(test.split())))
# Out:
# ''

# %% [markdown]
# remove_emoji handle

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
remove_emoji("Loved the movie. It was 😘😘")
# Out:
# 'Loved the movie. It was '

# %%
remove_emoji("Lmao 😂😂")
# Out:
# 'Lmao '

# %%
# !pip install emoji
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x102834690>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/emoji/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1028523d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/emoji/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1028685d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/emoji/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10280e750>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/emoji/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10285fb90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/emoji/
# ERROR: Could not find a version that satisfies the requirement emoji (from versions: none)
# ERROR: No matching distribution found for emoji

# %%
# show notebook kernel/python path (pure Python)
import sys
print(sys.executable, sys.version)
# Out:
# /Users/syedadilejaz/anaconda3/bin/python 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]

# %%
# run the same as a shell command from the notebook kernel
# !python -c "import sys; print(sys.executable, sys.version)"
# Out:
# /Users/syedadilejaz/anaconda3/bin/python 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]

# %%
# install emoji into the exact kernel interpreter (preferred for notebook)
import sys
# !{sys.executable} -m pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org emoji
# Out:
# Collecting emoji
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/e1/5e/4b5aaaabddfacfe36ba7768817bd1f71a7a810a43705e531f3ae4c690767/emoji-2.15.0-py3-none-any.whl.metadata
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 2.3 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0

# %%
import emoji
print(emoji.demojize('Python is 🔥'))
# Out:
# Python is :fire:

# %%
print(emoji.demojize('Loved the movie. It was 😘'))
# Out:
# Loved the movie. It was :face_blowing_a_kiss:

# %% [markdown]
# Tokenization

# %% [markdown]
# 1. Using the split function

# %%
# word tokenization
sent1 = 'I am going to delhi'
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# sentence tokenization
sent2 = 'I am going to delhi. I will stay there for 3 days. Let\'s hope the trip to be great'
sent2.split('.')
# Out:
# ['I am going to delhi',
#  ' I will stay there for 3 days',
#  " Let's hope the trip to be great"]

# %%
# Problems with split function
sent3 = 'I am going to delhi!'
sent3.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi!']

# %%
sent4 = 'Where do think I should go? I have 3 day holiday'
sent4.split('.')
# Out:
# ['Where do think I should go? I have 3 day holiday']

# %% [markdown]
# 2. Regular Expression

# %%
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ["Lorem Ipsum is simply dummy text of the printing and typesetting industry?\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %% [markdown]
# 3. NLTK

# %%
# ...existing code...
import nltk
nltk.download('punkt_tab', quiet=True)   # ensure punkt is available
from nltk.tokenize import word_tokenize, sent_tokenize

sent1 = 'I am going to visit delhi!'
print(word_tokenize(sent1))
# ...existing code...
# Out:
# ['I', 'am', 'going', 'to', 'visit', 'delhi', '!']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
sent5 = 'I have a Ph.D in A.I'
sent6 = "We're here to help! mail us at nks@gmail.com"
sent7 = 'A 5km ride cost $10.50'

word_tokenize(sent5)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'at',
#  'nks',
#  '@',
#  'gmail.com']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %% [markdown]
# 4. Spacy (good)

# %%
# !pip3 install spacy
# Out:
# Requirement already satisfied: spacy in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (0.26.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (5.2.1)
# Requirement already satisfied: httpx>=0.24.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: anyio in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.2.0)

# %%
# %pip install -U typing_extensions spacy
# Out:
# Requirement already satisfied: typing_extensions in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (4.15.0)
# Requirement already satisfied: spacy in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (0.26.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (5.2.1)
# Requirement already satisfied: httpx>=0.24.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: anyio in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/syedadilejaz/anaconda3/lib/python3.11/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys 
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(sent1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 doc1 = nlp(sent5)
#       2 doc2 = nlp(sent6)
#       3 doc3 = nlp(sent7)
#
# NameError: name 'sent5' is not defined

# %%
doc4 = nlp(sent1)
doc4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 doc4 = nlp(sent1)
#       2 doc4
#
# NameError: name 'nlp' is not defined

# %%
for token in doc4:
    print(token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 for token in doc4:
#       2     print(token)
#
# NameError: name 'doc4' is not defined

# %%
df.head()
# Out:
#                                               review sentiment  \
# 0  one    reviewers  mentioned   watching  1 oz e...  positive
# 1   wonderful little production  filming techniqu...  positive
# 2   thought    wonderful way  spend time    hot s...  positive
# 3  basically theres  family   little boy jake thi...  negative
# 4  petter matteis love   time  money   visually s...  positive
#
#                                         review_fixed  \
# 0  one of the other reviews has mentioned that af...
# 1  a wonderful little production the filling tech...
# 2  i thought this was a wonderful way to spend ti...
# 3  basically there a family where a little boy ja...
# 4  letter matters love in the time of money is a ...
#
#                                   review_fixed_spell
# 0  one of the other reviews has mentioned that af...
# 1  a wonderful little production the filling tech...
# 2  i thought this was a wonderful way to spend ti...
# 3  basically there a family where a little boy ja...
# 4  letter matters love in the time of money is a ...

# %% [markdown]
# Stemmer

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text = 'probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some 15 or more times in the last 25 years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie'
print(text)
# Out:
# probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some 15 or more times in the last 25 years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie

# %%
stem_words(text)
# Out:
# 'probabl my alltim favorit movi a stori of selfless sacrific and dedic to a nobl caus but it not preachi or bore it just never get old despit my have seen it some 15 or more time in the last 25 year paul luka perform bring tear to my eye and bett davi in one of her veri few truli sympathet role is a delight the kid are as grandma say more like dressedup midget than children but that onli make them more fun to watch and the mother slow awaken to what happen in the world and under her own roof is believ and startl if i had a dozen thumb theyd all be up for thi movi'

# %% [markdown]
# Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
wordnet_lemmatizer = WordNetLemmatizer()

sentence = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
punctuations="?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)

sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print ("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/syedadilejaz/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/syedadilejaz/nltk_data...
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[92], line 10
#       8 sentence = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
#       9 punctuations="?:!.,;"
# ---> 10 sentence_words = nltk.word_tokenize(sentence)
#      11 for word in sentence_words:
#      12     if word in punctuations:
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/punkt.py:1746, in PunktTokenizer.__init__(self, lang)
#    1744 def __init__(self, lang="english"):
#    1745     PunktSentenceTokenizer.__init__(self)
# -> 1746     self.load_lang(lang)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/punkt.py:1751, in PunktTokenizer.load_lang(self, lang)
#    1748 def load_lang(self, lang="english"):
#    1749     from nltk.data import find
# -> 1751     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1752     self._params = load_punkt_params(lang_dir)
#    1753     self._lang = lang
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/data.py:738, in find(resource_name, paths)
#     736 sep = "*" * 70
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'punkt_tab' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'tokenizers/punkt_tab/english/'
#
#   Searched in:
#     - '/Users/syedadilejaz/nltk_data'
#     - '/Users/syedadilejaz/anaconda3/nltk_data'
#     - '/Users/syedadilejaz/anaconda3/share/nltk_data'
#     - '/Users/syedadilejaz/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# NOTE: Stemming & lamatization are same to retrieve root words but lamatization is worked good. Lamatization is slow & stemming is fast
